# %% [markdown]
# # Oasis Infobyte
# # Data Science Internship
# # Task - 3
#
# ## Mohit Raje

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing *Dataset*

# %%
url="https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv"

# %%
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
numerics = ['int16', 'int32', 'int64' , 'float16' ,'float32' , 'float64' ]
dfnum = df.select_dtypes(include=numerics)

# %%
dfnum.head()
# Out:
#    car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0       1          3       88.6      168.8      64.1       48.8        2548
# 1       2          3       88.6      168.8      64.1       48.8        2548
# 2       3          1       94.5      171.2      65.5       52.4        2823
# 3       4          2       99.8      176.6      66.2       54.3        2337
# 4       5          2       99.4      176.6      66.4       54.3        2824
#
#    enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0         130       3.47    2.68               9.0         111     5000
# 1         130       3.47    2.68               9.0         111     5000
# 2         152       2.68    3.47               9.0         154     5000
# 3         109       3.19    3.40              10.0         102     5500
# 4         136       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# ...

# %%
print(df['CarName'].nunique())
print(df['CarName'].unique())
# Out:
# 147
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
#  'buick electra 225 custom' 'buick century luxus (sw)' 'buick century'
# ...

# %%
print(df['fueltype'].nunique())
print(df['fueltype'].unique())
# Out:
# 2
# ['gas' 'diesel']

# %%
print(df['carbody'].nunique())
print(df['carbody'].unique())
# Out:
# 5
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']

# %%
print(df['drivewheel'].nunique())
print(df['drivewheel'].unique())
# Out:
# 3
# ['rwd' 'fwd' '4wd']

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
grpobj=df.groupby('fueltype')

# %%
grpobj.mean()
# Out:
#               car_ID  symboling   wheelbase   carlength   carwidth  carheight  \
# fueltype
# diesel    125.600000   0.100000  104.390000  182.010000  67.430000  55.835000
# gas       100.556757   0.913514   98.147568  173.188649  65.743243  53.496757
#
#            curbweight  enginesize  boreratio    stroke  compressionratio  \
# fueltype
# diesel    2898.800000  135.700000   3.374500  3.485500         22.005000
# gas       2518.459459  125.956757   3.324919  3.230541          8.860108
#
#           horsepower     peakrpm   citympg  highwaympg       price
# fueltype
# diesel     84.450000  4435.00000  30.30000   34.750000  15838.1500
# gas       106.243243  5199.72973  24.67027   30.318919  12999.7982

# %%
grpobj.mean()['price']## It states that mean price of disel cars is more than that of the cars that run run on gas
# Out:
# fueltype
# diesel    15838.1500
# gas       12999.7982
# Name: price, dtype: float64

# %%
grpobj.mean()['horsepower']
# Out:
# fueltype
# diesel     84.450000
# gas       106.243243
# Name: horsepower, dtype: float64

# %%
grpobj.mean()['carlength']
# Out:
# fueltype
# diesel    182.010000
# gas       173.188649
# Name: carlength, dtype: float64

# %%
grpobj.mean()['carwidth']
# Out:
# fueltype
# diesel    67.430000
# gas       65.743243
# Name: carwidth, dtype: float64

# %%
grpobj.mean()['enginesize']
# Out:
# fueltype
# diesel    135.700000
# gas       125.956757
# Name: enginesize, dtype: float64

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
grpobj1=df.groupby('enginetype')

# %%
grpobj1.mean()
# Out:
#                 car_ID  symboling   wheelbase   carlength   carwidth  \
# enginetype
# dohc        119.166667   1.416667  100.433333  182.500000  66.400000
# dohcv       130.000000   1.000000   98.400000  175.700000  72.300000
# l           105.166667   0.166667  108.383333  186.966667  67.716667
# ohc          99.783784   0.770270   97.995946  171.953378  65.527703
# ohcf        141.200000   1.000000   94.840000  168.866667  64.960000
# ohcv         90.538462   0.769231  102.592308  185.592308  68.776923
# rotor        57.500000   3.000000   95.300000  169.000000  65.700000
#
#             carheight   curbweight  enginesize  boreratio    stroke  \
# enginetype
# dohc        52.733333  2976.833333  157.333333   3.403333  3.283333
# dohcv       50.500000  3366.000000  203.000000   3.940000  3.110000
# l           56.850000  3076.583333  129.583333   3.526667  3.149167
# ohc         53.779730  2422.344595  117.540541   3.260946  3.326486
# ...

# %%
grpobj2=df.groupby('enginelocation')

# %%
grpobj2.mean()
# Out:
#                     car_ID  symboling  wheelbase   carlength   carwidth  \
# enginelocation
# front           102.628713    0.80198  98.894059  174.125743  65.921287
# rear            128.000000    3.00000  89.500000  168.900000  65.000000
#
#                 carheight   curbweight  enginesize  boreratio    stroke  \
# enginelocation
# front           53.756436  2552.371287  125.910891   3.323663  3.260693
# rear            51.600000  2770.666667  194.000000   3.740000  2.900000
#
#                 compressionratio  horsepower      peakrpm    citympg  \
# enginelocation
# front                  10.152079  102.589109  5113.613861  25.341584
# rear                    9.500000  207.000000  5900.000000  17.000000
#
#                 highwaympg         price
# enginelocation
# front            30.836634  12961.097361
# rear             25.000000  34528.000000

# %%
grpobj2.mean()['price']
# Out:
# enginelocation
# front    12961.097361
# rear     34528.000000
# Name: price, dtype: float64

# %%
grpobj3=df.groupby('cylindernumber')

# %%
grpobj3.mean()
# Out:
#                     car_ID  symboling   wheelbase   carlength   carwidth  \
# cylindernumber
# eight            84.800000   0.800000  108.700000  193.180000  71.640000
# five             46.818182   0.363636  105.345455  187.481818  69.481818
# four            110.339623   0.811321   97.756604  171.400000  65.305660
# six              97.208333   0.833333  101.162500  182.937500  67.137500
# three            19.000000   2.000000   88.400000  141.100000  60.300000
# twelve           50.000000   0.000000  102.000000  191.700000  70.600000
# two              57.500000   3.000000   95.300000  169.000000  65.700000
#
#                 carheight   curbweight  enginesize  boreratio    stroke  \
# cylindernumber
# eight           53.980000  3681.200000  256.600000   3.692000  3.202000
# five            55.290909  3132.636364  152.181818   3.320909  3.487273
# four            53.803145  2394.515723  112.798742   3.305912  3.236730
# ...

# %% [markdown]
# ## Data Visualization

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(10 , 10))
plt.subplot(2 , 2 ,1)
sns.barplot(x='fueltype', y='price' , data=df)
plt.subplot(2 , 2 ,2)
sns.barplot(x='fueltype' , y='horsepower' , data=df)
plt.tight_layout()
plt.subplot(2 , 2 ,3)
sns.barplot(x='fueltype' , y='carlength' , data=df)
plt.subplot(2 , 2 ,4)
sns.barplot(x='fueltype' , y='carwidth' , data=df)

# %%
fig=plt.figure(figsize=(10 , 10))
plt.subplot(2 , 2 , 1)
sns.boxplot(x='fueltype' , y='price' , data=df)
plt.subplot(2 , 2 , 2)
sns.boxplot(x='fueltype' , y='horsepower' , data=df)
plt.subplot(2 , 2 , 3)
sns.boxplot(x='fueltype' , y='carlength' , data=df)
plt.subplot(2 , 2 , 4)
sns.boxplot(x='fueltype' , y='carwidth' , data=df)
plt.tight_layout()

# %%
fig=plt.figure(figsize=(10,10))
plt.subplot(2,  2 ,1)
sns.barplot(x='enginetype' , y='price' , data=df)
plt.subplot(2,  2 ,2)
sns.barplot(x='enginetype' , y='horsepower' , data=df)
plt.tight_layout()

# %%
import plotly.express as px
fig=px.pie(df , names='fueltype' , values='price'  , title='fueltype')
fig.update_traces(textinfo='percent + label')
fig.update_layout(autosize=False , width=500 , height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.pie(df , names='enginetype'  , values='price' , title='enginetype')
fig=fig.update_traces(textinfo='percent + label')
fig.update_layout(autosize=False , height=500 , width=500)
plt.tight_layout()
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.pie(df , names='cylindernumber' , values='price' , title='cylindernumber')
fig.update_traces(textinfo="percent +label")
fig.update_layout(autosize=False  , width=600 , height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.sunburst(df , path=['fueltype' ,'enginetype'])
fig.update_layout(autosize=False , width=600 , height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.sunburst(df , path=['fueltype' , 'CarName'])
fig.update_layout(autosize=False , width=600 , height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
fig=plt.figure(figsize=(10 , 10))
sns.heatmap(df.corr())

# %% [markdown]
# ## Import train_test_split

# %%
temp=dfnum.iloc[: , 2:-1]
temp
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
dfnum.head()
X=dfnum.iloc[: , 2:-1]
Y=dfnum.iloc[: , -1]

# %%
X.head()
# Out:
#    wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0       88.6      168.8      64.1       48.8        2548         130
# 1       88.6      168.8      64.1       48.8        2548         130
# 2       94.5      171.2      65.5       52.4        2823         152
# 3       99.8      176.6      66.2       54.3        2337         109
# 4       99.4      176.6      66.4       54.3        2824         136
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg
# 0          27
# 1          27
# 2          26
# 3          30
# 4          22

# %%
Y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X  , Y , test_size=0.3 , random_state=101)

# %%
X_train.shape
# Out:
# (143, 13)

# %%
X_test.shape
# Out:
# (62, 13)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %% [markdown]
# ## Training model

# %%
model.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Making Prediction

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# ## Checking accuracy of model

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error , r2_score

# %%
mse=mean_squared_error(Y_test , y_pred)
mae=mean_absolute_error(Y_test , y_pred)
r2=r2_score(Y_test  , y_pred)

print("Mean squared error is {}".format(mse))
print("Mean absolute error is {}".format(mae))
print("r2 score : {}".format(r2))
# Out:
# Mean squared error is 11848918.384213353
# Mean absolute error is 2309.777336421824
# r2 score : 0.8265466494300029

# %% [markdown]
# ## Prediction the output for users input

# %%
import warnings
warnings.filterwarnings('ignore')

wheelbase=float(input("Enter the wheelbase : "))
carlength=float(input("Enter the carlength : "))
carwidth=float(input("Enter the carwidth : "))	
carheight=float(input("Enter the carheight : "))
curbweight=float(input("Enter the carweight : "))	
enginesize=float(input("Enter the enginesize : "))	
boreratio=float(input("Enter the boreratio : "))	
stroke=float(input("Enter the stroke : "))	
compressionratio=float(input("Enter the compressionratio : "))	
horsepower=float(input("Enter the horsepower : "))	
peakrpm=float(input("Enter the peakrpm : "))
citympg=float(input("Enter the citympg : "))
highwaympg=float(input("Enter the highwaympg : "))

ls=[wheelbase , carlength , carwidth , carheight ,curbweight ,enginesize,boreratio, stroke , compressionratio , horsepower ,peakrpm ,citympg ,highwaympg ]
arr=np.array(ls)
arr=arr.reshape(1 , -1)

result=model.predict(arr)
print("Price of the car is : {}".format(result))
# Out:
# Enter the wheelbase : 88.6
# Enter the carlength : 168.8
# Enter the carwidth : 64.1
# Enter the carheight : 48.8
# Enter the carweight : 2548
# Enter the enginesize : 130
# Enter the boreratio : 3.47
# Enter the stroke : 2.68
# Enter the compressionratio : 9.0
# Enter the horsepower : 111
# Enter the peakrpm : 5000
# Enter the citympg : 21
# Enter the highwaympg : 27
# Price of the car is : [13415.59433869]
